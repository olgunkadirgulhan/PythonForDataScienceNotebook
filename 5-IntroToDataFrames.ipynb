# %%
import pandas as pd
import numpy as np

# %%
data = np.random.randn(4,3)

# %%
data
# Out:
# array([[-0.88771122, -0.65674986, -1.33122416],
#        [ 0.38069418,  1.38736329, -0.90183987],
#        [ 0.48879275,  2.00798623,  1.97248646],
#        [ 0.30468905, -1.74341711, -0.06367991]])

# %%
data_frame=pd.DataFrame(data)

# %%
data_frame
# Out:
#           0         1         2
# 0 -0.887711 -0.656750 -1.331224
# 1  0.380694  1.387363 -0.901840
# 2  0.488793  2.007986  1.972486
# 3  0.304689 -1.743417 -0.063680

# %%
type(data_frame)
# Out:
# pandas.core.frame.DataFrame

# %%
data_frame[0]
# Out:
# 0   -0.887711
# 1    0.380694
# 2    0.488793
# 3    0.304689
# Name: 0, dtype: float64

# %%
type(data_frame[0])
# Out:
# pandas.core.series.Series

# %%
new_df = pd.DataFrame(data,index=["Olgun","Kadir", "Gülhan","Recep"], columns=["Salary","Age","Seniority"])

# %%
new_df
# Out:
#           Salary       Age  Seniority
# Olgun  -0.887711 -0.656750  -1.331224
# Kadir   0.380694  1.387363  -0.901840
# Gülhan  0.488793  2.007986   1.972486
# Recep   0.304689 -1.743417  -0.063680

# %%
new_df["Age"]
# Out:
# Olgun    -0.656750
# Kadir     1.387363
# Gülhan    2.007986
# Recep    -1.743417
# Name: Age, dtype: float64

# %%
new_df['Salary']
# Out:
# Olgun    -0.887711
# Kadir     0.380694
# Gülhan    0.488793
# Recep     0.304689
# Name: Salary, dtype: float64

# %%
new_df[['Salary','Age']]
# Out:
#           Salary       Age
# Olgun  -0.887711 -0.656750
# Kadir   0.380694  1.387363
# Gülhan  0.488793  2.007986
# Recep   0.304689 -1.743417

# %%
new_df.loc['Olgun']
# Out:
# Salary      -0.887711
# Age         -0.656750
# Seniority   -1.331224
# Name: Olgun, dtype: float64

# %%
new_df.iloc[0]
# Out:
# Salary      -0.887711
# Age         -0.656750
# Seniority   -1.331224
# Name: Olgun, dtype: float64

# %%
new_df["Extras"]=10

# %%
new_df
# Out:
#           Salary       Age  Seniority  Extras
# Olgun  -0.887711 -0.656750  -1.331224      10
# Kadir   0.380694  1.387363  -0.901840      10
# Gülhan  0.488793  2.007986   1.972486      10
# Recep   0.304689 -1.743417  -0.063680      10

# %%
new_df.drop("Extras", axis=1 ,inplace=True)

# %%
new_df.drop("Recep", axis=0 )
# Out:
#           Salary       Age  Seniority
# Olgun  -0.887711 -0.656750  -1.331224
# Kadir   0.380694  1.387363  -0.901840
# Gülhan  0.488793  2.007986   1.972486

# %%
new_df
# Out:
#           Salary       Age  Seniority
# Olgun  -0.887711 -0.656750  -1.331224
# Kadir   0.380694  1.387363  -0.901840
# Gülhan  0.488793  2.007986   1.972486
# Recep   0.304689 -1.743417  -0.063680

# %%
new_df.loc["Olgun"]
# Out:
# Salary      -0.887711
# Age         -0.656750
# Seniority   -1.331224
# Name: Olgun, dtype: float64

# %%
new_df.loc["Olgun"]["Salary"]
# Out:
# np.float64(-0.8877112184280008)

# %%
new_df.iloc[0].iloc[0]
# Out:
# np.float64(-0.8877112184280008)

# %%
boolean_frame = new_df >1

# %%
boolean_frame
# Out:
#         Salary    Age  Seniority
# Olgun    False  False      False
# Kadir    False   True      False
# Gülhan   False   True       True
# Recep    False  False      False

# %%
new_df[boolean_frame]
# Out:
#         Salary       Age  Seniority
# Olgun      NaN       NaN        NaN
# Kadir      NaN  1.387363        NaN
# Gülhan     NaN  2.007986   1.972486
# Recep      NaN       NaN        NaN

# %%
new_df[new_df>0]
# Out:
#           Salary       Age  Seniority
# Olgun        NaN       NaN        NaN
# Kadir   0.380694  1.387363        NaN
# Gülhan  0.488793  2.007986   1.972486
# Recep   0.304689       NaN        NaN

# %%
new_df.reset_index()
# Out:
#     index    Salary       Age  Seniority
# 0   Olgun -0.887711 -0.656750  -1.331224
# 1   Kadir  0.380694  1.387363  -0.901840
# 2  Gülhan  0.488793  2.007986   1.972486
# 3   Recep  0.304689 -1.743417  -0.063680

# %%
new_indices = ["ogi","kado","ali","şükrü"]

# %%
new_df["NewIndex"] = new_indices

# %%
new_df
# Out:
#           Salary       Age  Seniority NewIndex
# Olgun  -0.887711 -0.656750  -1.331224      ogi
# Kadir   0.380694  1.387363  -0.901840     kado
# Gülhan  0.488793  2.007986   1.972486      ali
# Recep   0.304689 -1.743417  -0.063680    şükrü

# %%
new_df.set_index("NewIndex", inplace=True)

# %%
new_df
# Out:
#             Salary       Age  Seniority
# NewIndex
# ogi      -0.887711 -0.656750  -1.331224
# kado      0.380694  1.387363  -0.901840
# ali       0.488793  2.007986   1.972486
# şükrü     0.304689 -1.743417  -0.063680

# %%
new_df.loc["ogi"]
# Out:
# Salary      -0.887711
# Age         -0.656750
# Seniority   -1.331224
# Name: ogi, dtype: float64

# %%
first_index = ["Simpson","Simpson","Simpson","South Park", "South Park", "South Park"]

# %%
inner_index = ["Homer","Bart","Marge","Cartman","Kenny","Kyle"]

# %%
zipped_index= list(zip(first_index,inner_index))

# %%
zipped_index
# Out:
# [('Simpson', 'Homer'),
#  ('Simpson', 'Bart'),
#  ('Simpson', 'Marge'),
#  ('South Park', 'Cartman'),
#  ('South Park', 'Kenny'),
#  ('South Park', 'Kyle')]

# %%
zipped_index= pd.MultiIndex.from_tuples(zipped_index)

# %%
zipped_index
# Out:
# MultiIndex([(   'Simpson',   'Homer'),
#             (   'Simpson',    'Bart'),
#             (   'Simpson',   'Marge'),
#             ('South Park', 'Cartman'),
#             ('South Park',   'Kenny'),
#             ('South Park',    'Kyle')],
#            )

# %%
sample_values = np.ones((6,2))

# %%
big_df = pd.DataFrame(data=sample_values,index=zipped_index,columns=["Age","Salary"])

# %%
big_df
# Out:
#                     Age  Salary
# Simpson    Homer    1.0     1.0
#            Bart     1.0     1.0
#            Marge    1.0     1.0
# South Park Cartman  1.0     1.0
#            Kenny    1.0     1.0
#            Kyle     1.0     1.0

# %%
big_df.loc["Simpson"]
# Out:
#        Age  Salary
# Homer  1.0     1.0
# Bart   1.0     1.0
# Marge  1.0     1.0

# %%
big_df.loc['Simpson'].loc["Homer"]
# Out:
# Age       1.0
# Salary    1.0
# Name: Homer, dtype: float64

# %%
big_df.iloc[0].iloc[0]
# Out:
# np.float64(1.0)
