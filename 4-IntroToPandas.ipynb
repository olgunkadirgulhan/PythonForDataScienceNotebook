# %%
import numpy as np
import pandas as pd

# %%
grades = {"Olgun" : 35 , "Kadir" : 31 , "Gülhan" : 15  }

# %%
pd.Series(grades)
# Out:
# Olgun     35
# Kadir     31
# Gülhan    15
# dtype: int64

# %%
names = ['Olgun','Kadir','Gülhan']
ages = [35,31,15]

# %%
pd.Series(names)
# Out:
# 0     Olgun
# 1     Kadir
# 2    Gülhan
# dtype: object

# %%
pd.Series(ages)
# Out:
# 0    35
# 1    31
# 2    15
# dtype: int64

# %%
pd.Series(names,ages)
# Out:
# 35     Olgun
# 31     Kadir
# 15    Gülhan
# dtype: object

# %%
pd.Series(ages, names)
# Out:
# Olgun     35
# Kadir     31
# Gülhan    15
# dtype: int64

# %%
pd.Series(data = ages, index= names)
# Out:
# Olgun     35
# Kadir     31
# Gülhan    15
# dtype: int64

# %%
# with numpy

# %%
numpy_array = np.array([40,50,30,20])

# %%
pd.Series(numpy_array)
# Out:
# 0    40
# 1    50
# 2    30
# 3    20
# dtype: int64

# %%
#arithmetic

# %%
contest_result = pd.Series([10,5,100],["Olgun","James","Lars"])

# %%
contest_result2 = pd.Series([55,25,1200],["Olgun","James","Lars"])

# %%
contest_result['Olgun']
# Out:
# np.int64(10)

# %%
contest_result2['Lars']
# Out:
# np.int64(1200)

# %%
final_result = contest_result + contest_result2

# %%
final_result
# Out:
# Olgun      65
# James      30
# Lars     1300
# dtype: int64

# %%
# if indices are different

# %%
different_series = pd.Series([20,30,40,50],["a","b","c","d"])

# %%
different_series_2 = pd.Series([10,5,3,1],["a","c","f","g"])

# %%
different_series + different_series_2
# Out:
# a    30.0
# b     NaN
# c    45.0
# d     NaN
# f     NaN
# g     NaN
# dtype: float64
